# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dat = np.load("signs_matched/val_matched.npz", allow_pickle=True)

# %%
plt.imshow(dat["hotspots"][3])

# %%
dat["gt_classes"][3]
# Out:
# 7
